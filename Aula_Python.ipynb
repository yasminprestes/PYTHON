# %% [markdown]
# <a href="https://colab.research.google.com/github/yasminprestes/PYTHON/blob/main/Aula_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Aula 1**  🌊 🇾 ❣

# %%
print ("I competição de programação da start")
ano = "IX"
print ("{ano} competição de programa da start")
# Out:
# IX competição de programação da Start

# %% [markdown]
# #**Aula 2** ❄ ✈ ☀

# %%
livro_ficcao = 8
livro_n_ficcao = 10
livro_infantil = 6
pontos_rodrigo = livro_ficcao + livro_n_ficcao + livro_infantil
pontos_ana = 2 * livro_ficcao + 5 * livro_infantil
pontos_totais = pontos_rodrigo + pontos_ana
print(f"Os pontos totais do Rodrigo são {pontos_rodrigo}")
print(f"Os pontos totais do Ana são {pontos_ana}")
print(f"Os pontos totais do Rodrigo e de ana são {pontos_totais}")

# %% [markdown]
# # **Aula 3** **tabuada** 📸 ⚓ ✈

# %%
def tabuada(numero):
    for contador in range(1, 11):  # Gera números de 1 a 10
        print(f"{numero} x {contador} = {numero * contador}")
numero = int(input("Digite um número para ver sua tabuada: "))
tabuada(numero)

# %% [markdown]
# # **Aula 4 IMC** 🪐 📡 👾

# %%
peso = float(input("Digite seu peso (em kg): "))
altura = float(input("Digite sua altura (em metros): "))
imc = peso / (altura ** 2)
print(f"\nSeu IMC é: {imc:.2f}")
if imc < 18.5:
    print("Você está abaixo do peso.")
elif 18.5 <= imc < 25:
    print("Você está no peso ideal.")
elif 25 <= imc < 30:
    print("Você está com sobrepeso.")
else:
    print("Você está acima do peso.")

# %% [markdown]
# # **Aula 5** 🍠 🍅 🍀

# %%
print("Olá, sou seu assistente virtual, em que posso ajudar?")
nome = input("Digite seu nome: ")
resposta = input(f"Olá {nome}, qual tema você deseja conversar? Python, Javascript ou matemática: ").lower ()
if resposta == "python":
  print(f"Ótimo {nome}, vamos falar sobre Python. \n Python é uma linguagem de programação simples, poderosa e versátil, ideal para iniciantes e profissionais em diversas áreas da tecnologia.")
if resposta == "javascript":
  print(f"Ótimo {nome}, vamos falar sobre javascript. \n JavaScript é uma linguagem de programação versátil usada principalmente para criar interatividade e dinamismo em páginas web.")
if resposta == "matemática":
  print(f"Ótimo {nome}, vamos falar sobre matemática. \n A matemática é a ciência que estuda padrões, estruturas, quantidades e formas, buscando compreender e descrever logicamente o mundo por meio de números, símbolos e relações.")
else:
  print(f"Ótimo {nome}, não sei falar sobre esse assunto.")
# Out:
# Olá, sou seu assistente virtual, em que posso ajudar?
# Digite seu nome: yasmin
# Olá yasmin, qual tema você deseja conversar? Python, Javascript ou matemática: matemática
# Ótimo yasmin, vamos falar sobre matemática.

# %% [markdown]
# # **Aula 6** **Listas** ⏯ ⚛ ❤

# %%
import random
dicas = [
"Acredite em você e tudo será possível. 💪",
"Não desista, o sucesso está logo ali. 🌟",
"Cada passo é um avanço para o seu sonho. 👣",
"A jornada é difícil, mas a vitória é doce. 🏆",
"O impossível é apenas uma opinião. ✨",
"Transforme seus medos em força. 🔥",
"O sucesso começa com a decisão de tentar. 🚀",
"A cada desafio, você se torna mais forte. 💥",
"O futuro pertence a quem acredita nos seus sonhos. 🌈",
"Você tem o poder de criar sua própria realidade. 🔮",
]
while True:
  pedido = input("Digite 'dica' para receber uma dica ou 'sair' para encerrar \n ").lower()

  if pedido == "dica":
    dica = random.choice(dicas) # escolhe uma dica aleatória sair
    print(f"Dica: {dica} \n")

  elif pedido == "sair":
    print("Até a próxima! \n")
    break
  else:
    print("Comando inválido. Tente novamente. \n")
    break
# Out:
# Digite 'dica' para receber uma dica ou 'sair' para encerrar
#  dica
# Dica: Cada passo é um avanço para o seu sonho. 👣
